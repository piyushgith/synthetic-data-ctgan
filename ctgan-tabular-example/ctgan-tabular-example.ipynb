# %%
#!pip install sdv pyspark

# %%
from ctgan import CTGAN
from ctgan import load_demo

real_data = load_demo()

# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan = CTGAN(epochs=10)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(1000)

# %%
synthetic_data.head(5)
# Out:
#    age         workclass  fnlwgt     education  education-num  \
# 0   54           Private  145833  Some-college             13
# 1   55           Private  129925       HS-grad             10
# 2   22         Local-gov  154491       HS-grad              9
# 3   31           Private  319275       7th-8th             10
# 4   30  Self-emp-not-inc   45164       HS-grad             10
#
#        marital-status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse       Tech-support        Husband  White  Female
# 1  Married-civ-spouse  Machine-op-inspct      Own-child  White    Male
# 2  Married-civ-spouse       Adm-clerical        Husband  White    Male
# 3       Never-married    Exec-managerial      Own-child  White    Male
# 4       Never-married       Adm-clerical  Not-in-family  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0           -59             4              40  United-States  <=50K
# 1          -110             0              40  United-States  <=50K
# 2          -123             6              40  United-States   >50K
# 3           -76             2              40  United-States   >50K
# 4           -88             3              49  United-States  <=50K

# %%
synthetic_data.to_csv('synthetic-data-example.csv')
